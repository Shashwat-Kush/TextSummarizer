# %%
d = {'key':'value','key1':'value1'}

# %%
d['key']
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({'key':'value','key1':'value1'})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x:int,y:int)->int:
    return x*y

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_product(2,"4")
#
# File ~/Desktop/ML/TextSummarizer/venv/lib/python3.10/site-packages/ensure/main.py:855, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#     851     msg = (
#     852         "Return value of {f} of type {valt} "
#     853         "does not match annotation type {t}"
#     854     )
# --> 855     raise EnsureError(msg.format(
#     856         f=self.f, t=self.return_templ, valt=type(return_val)
#     857     ))
#     858 return return_val
#
# EnsureError: Return value of <function get_product at 0x10aad3400> of type <class 'str'> does not match annotation type <class 'int'>
